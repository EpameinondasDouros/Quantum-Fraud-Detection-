# %% [markdown]
# ### Data Loading

# %%
import pandas as pd

# %%
# Install the Kaggle library
# !pip install kaggle

# Upload kaggle.json file
from google.colab import files
files.upload()  # This will prompt you to upload kaggle.json

# Make a directory for Kaggle and move the file there
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Now you can download the dataset
# !kaggle datasets download -d ealaxi/paysim1 -p /content/datasets --unzip

print("Dataset downloaded to: /content/datasets")
# Out:
# ...
#      <input type="file" id="files-9b96e76b-2bdf-4f6e-9f09-04a760d92bcf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b96e76b-2bdf-4f6e-9f09-04a760d92bcf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
full_df=pd.read_csv("/content/datasets/PS_20174392719_1491204439457_log.csv",delimiter=',')

# %%
full_df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
nRowsRead = 1000000

big_df = pd.read_csv("/content/datasets/PS_20174392719_1491204439457_log.csv",delimiter=',',nrows=nRowsRead)

# %%
big_df
# Out:
#         step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0          1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1          1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2          1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3          1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4          1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# ...      ...       ...       ...          ...            ...             ...
# 999995    45   PAYMENT  10913.42  C1384914558      576108.80       565195.38
# 999996    45   PAYMENT   2014.46  C1207593845      565195.38       563180.92
# 999997    45   PAYMENT  18839.45   C260638437      563180.92       544341.47
# 999998    45   PAYMENT  17890.19   C439661237      544341.47       526451.29
# 999999    45   PAYMENT  25411.16  C1142299632      526451.29       501040.13
#
# ...

# %%
nRowsRead = 100000
# Load the dataset (replace with actual filename if needed)
df = pd.read_csv("/content/datasets/PS_20174392719_1491204439457_log.csv",delimiter=',',nrows=nRowsRead)
print(df.head())
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %% [markdown]
# ## Data Processing

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Find the size of the DataFrame
df_size = df.shape
print("Number of rows:", df_size[0])
print("Number of columns:", df_size[1])
# Out:
# Number of rows: 100000
# Number of columns: 11

# %%
type_counts = df['type'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(type_counts, labels=type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Types')
plt.show()

# %%
import matplotlib.pyplot as plt

# Group by 'type' and 'isfraud' to get counts of fraud cases per type
type_fraud_counts = df.groupby('type')['isFraud'].sum()

# Plot the bar chart
plt.figure(figsize=(10, 6))
type_fraud_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Type')
plt.ylabel('Number of Fraud Cases')
plt.title('Fraud Cases by Type')
plt.xticks(rotation=45)
plt.show()

# %%
amount_range = (df['amount'].min(), df['amount'].max())
print("\nRange of 'amount' Column (Min, Max):", amount_range)
# Out:
# Range of 'amount' Column (Min, Max): (0.32, 10000000.0)

# %%
# Fraudulent vs Non-Fraudulent Transactions
print(df['isFraud'].value_counts(normalize=True) * 100)

# Flagged vs Non-Flagged Transactions
print(df['isFlaggedFraud'].value_counts(normalize=True) * 100)
# Out:
# isFraud
# 0    99.884
# 1     0.116
# Name: proportion, dtype: float64
# isFlaggedFraud
# 0    100.0
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df[df['amount'] <= 100000]['amount'], bins=50, kde=True)
plt.title("Distribution of Transaction Amounts (Limited to 100,000)")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.xlim(0, 100000)  # Set the limit for the x-axis
plt.show()

# %%
# Separate fraud and non-fraud transactions
fraud_df = df[df['isFraud'] == 1]
non_fraud_df = df[df['isFraud'] == 0]

# %%
print(fraud_df.shape)
# Out:
# (116, 11)

# %%
# Calculate the number of non-fraud samples needed for a 95:5 ratio
desired_non_fraud_count = int(len(fraud_df) * (95 / 5))

# Randomly sample the non-fraud data to the desired count
non_fraud_sampled = non_fraud_df.sample(n=desired_non_fraud_count, random_state=42)

# %%
balanced_df = pd.concat([fraud_df, non_fraud_sampled])

# %%
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)
print(balanced_df['isFraud'].value_counts(normalize=True) * 100)
# Out:
# isFraud
# 0    95.0
# 1     5.0
# Name: proportion, dtype: float64

# %% [markdown]
# ## Quantum Processing

# %%
pip install qiskit

# %%
pip install pylatexenc

# %%
from qiskit import QuantumCircuit
from qiskit.visualization import plot_histogram
from qiskit.circuit.library import TwoLocal,ZZFeatureMap,PauliFeatureMap

import numpy as np

# %%
feature_dimension = 3  # Number of features/qubits
reps = 1  # Number of repetitions
entanglement = 'full'  # Entanglement strategy

feature_map = ZZFeatureMap(feature_dimension=feature_dimension, reps=reps, entanglement=entanglement)

# %%
feature_map.decompose().draw('mpl')

# %%
feature_map.num_qubits
# Out:
# 3

# %%
print(feature_map.feature_dimension)
# Out:
# 3

# %%
feature_map.data
# Out:
# [CircuitInstruction(operation=Instruction(name='ZZFeatureMap', num_qubits=3, num_clbits=0, params=[ParameterVectorElement(x[0]), ParameterVectorElement(x[1]), ParameterVectorElement(x[2])]), qubits=(Qubit(QuantumRegister(3, 'q'), 0), Qubit(QuantumRegister(3, 'q'), 1), Qubit(QuantumRegister(3, 'q'), 2)), clbits=())]

# %%
sample_data = np.array([0.1, 0.2, 0.3])  # Example data point
bound_circuit = feature_map.assign_parameters(sample_data)

# %%
bound_circuit.decompose().draw('mpl')

# %% [markdown]
# ### From here we are implementing the Quantum Support Vector Machine.
#
# It's gonna have fake data and gonna use:
#
# --- EfficientSU2, which is a variational circuit which introduces trainable parameters to the circuit.
#
# This tools is retrieved from the package:
#
# from qiskit.circuit.library import EfficientSU2
#
# More about EfficientSU2 in the next cells
#
# --- Quantum Kernels

# %%
from qiskit.circuit.library import EfficientSU2
from qiskit import QuantumCircuit

# Define the variational circuit
variational_circuit = EfficientSU2(num_qubits=feature_dimension, reps=1)

# Combine the feature map and variational circuit

#Fisrt we intialize a quantum circuit with the necessary number of qubits
quantum_model = QuantumCircuit(feature_map.num_qubits)

#Now we are gonna add the feature_map and the variational circuit
quantum_model.compose(feature_map, inplace=True)
quantum_model.compose(variational_circuit, inplace=True)

# %%
quantum_model.draw('mpl')

# %% [markdown]
# #### Now we are gonna use an already established implementaion

# %%
pip install qiskit_machine_learning

# %%
from qiskit_machine_learning.kernels import FidelityQuantumKernel

quantum_kernel = FidelityQuantumKernel(feature_map=feature_map)

# %% [markdown]
# ##### Now we use the established method QSVC toghether with the Quantum Kernel we created just above

# %%
pip install qiskit_aer

# %%
from qiskit_machine_learning.algorithms import QSVC
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
data = load_iris()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
# Initialize and train the QSVC
qsvc = QSVC(quantum_kernel=quantum_kernel)
qsvc.fit(X_train, y_train)

# Evaluate the model
accuracy = qsvc.score(X_test, y_test)
print(f"Model accuracy: {accuracy * 100:.2f}%")
# Out:
# Model accuracy: 86.67%

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# %%
# Now we check the accuracy of a classical svm for comparison

svc = SVC(kernel='rbf', gamma='scale')
svc.fit(X_train, y_train)

# Evaluate----------------------------------------------------------
y_pred = svc.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Classical Model accuracy: {accuracy * 100:.2f}%")
# Out:
# Classical Model accuracy: 100.00%

# %%
from qiskit_aer import AerSimulator
from qiskit.primitives import Sampler
from qiskit_algorithms.state_fidelities import ComputeUncompute

# %%
simulator = AerSimulator()
fidelity = ComputeUncompute(sampler=Sampler())
# Out:
# <ipython-input-36-bbf2f37cc4ae>:2: DeprecationWarning: The class ``qiskit.primitives.sampler.Sampler`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseSamplerV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Sampler` class is `StatevectorSampler`.
#   fidelity = ComputeUncompute(sampler=Sampler())

# %%
# quantum_instance = AerSimulator()  # Using the updated AerSimulator
quantum_kernel = FidelityQuantumKernel(feature_map=feature_map, fidelity=fidelity)

# %%
num_samples = 4  # Number of data samples
X = np.random.rand(num_samples, feature_map.num_qubits)  # Randomly generated data

simulator = AerSimulator()
kernel_matrix = quantum_kernel.evaluate(X)

# %%
print(kernel_matrix)
# Out:
# [[1.         0.02372254 0.16277982 0.02979584]
#  [0.02372254 1.         0.03167869 0.10624684]
#  [0.16277982 0.03167869 1.         0.33800757]
#  [0.02979584 0.10624684 0.33800757 1.        ]]

# %% [markdown]
# ## Quantum Machine Learning On Kaggle Dataset

# %%
balanced_df.head()
# Out:
#    step      type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0    10   PAYMENT    23454.67   C457872877           0.00            0.00
# 1     8   CASH_IN   584691.28  C1143751326     9393939.23      9978630.51
# 2     9  TRANSFER  1154353.99   C670587931     1154353.99            0.00
# 3     9   PAYMENT     3212.49  C1007314489        7786.00         4573.51
# 4    10   CASH_IN    96961.95  C1798459201      383588.61       480550.55
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0   M772738847            0.00            0.00        0               0
# 1   C580431625      1524938.60       866827.55        0               0
# 2   C150406565            0.00        10872.90        1               0
# 3  M1214856516            0.00            0.00        0               0
# 4   C667395488       824028.22       995103.55        0               0

# %%
X = pd.get_dummies(balanced_df, columns=['type'])
X = X.loc[:, ~X.columns.str.contains('name')]
X = X.astype(int)

# %%
y = X['isFraud']
X = X.drop(columns=['isFraud'])

# %%
print(X)
# Out:
#       step   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0       10    23454              0               0               0
# 1        8   584691        9393939         9978630         1524938
# 2        9  1154353        1154353               0               0
# 3        9     3212           7786            4573               0
# 4       10    96961         383588          480550          824028
# ...    ...      ...            ...             ...             ...
# 2315     7   285481              0               0         1260559
# 2316     9     4758          10549            5790               0
# 2317     9    83596          21279          104875               0
# 2318     8   226509        4551465         4777974        13879020
# 2319     8   297838            175               0           13216
#
#       newbalanceDest  isFlaggedFraud  type_CASH_IN  type_CASH_OUT  type_DEBIT  \
# 0                  0               0             0              0           0
# ...

# %% [markdown]
# **The Feature Seleciton part skip for now**

# %% [markdown]
# #### Feature Selection

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
print(X_scaled[:5])
# Out:
# [[ 0.761091   -0.1973695  -0.38361614 -0.39733461 -0.3277926  -0.33270478
#    4.35889894  0.         -0.47108676  2.47394803 -0.17407766 -1.08283146
#   -0.34944558]
#  [ 1.16416101 -0.25136703 -0.38855589 -0.38920341 -0.3277926  -0.34354516
#   -0.22941573  0.         -0.47108676 -0.40421221 -0.17407766  0.92350476
#   -0.34944558]
#  [-0.85118901 -0.25612449 -0.36478379 -0.36430117 -0.30166624 -0.31949182
#   -0.22941573  0.         -0.47108676 -0.40421221  5.74456265 -1.08283146
#   -0.34944558]
#  [ 1.16416101 -0.26085589 -0.39966702 -0.39733461 -0.3277926  -0.34354516
#   -0.22941573  0.         -0.47108676 -0.40421221 -0.17407766  0.92350476
#   -0.34944558]
#  [ 0.761091    0.39395419 -0.24742529 -0.08609533  1.16772758  1.30953586
#   -0.22941573  0.          2.12275125 -0.40421221 -0.17407766 -1.08283146
#   -0.34944558]]

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=X.shape[1])
X_pca = pca.fit_transform(X_scaled)

# Step 3: Explained Variance Ratio Plot
# This helps you understand how much variance each principal component explains
plt.figure(figsize=(10, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o', linestyle='--')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Principal Components')
plt.show()

# %%
loading_scores = pd.DataFrame(pca.components_.T, columns=[f'PC{i+1}' for i in range(X.shape[1])], index=X.columns)

# Display the loading scores
print("Loading scores for each feature in the principal components:")
print(loading_scores)
# Out:
# Loading scores for each feature in the principal components:
#                      PC1       PC2       PC3       PC4       PC5       PC6  \
# amount          0.138686 -0.449447 -0.298582 -0.172129  0.775016  0.199622
# oldbalanceOrg   0.546220  0.104731 -0.049980 -0.047162  0.166918 -0.423187
# newbalanceOrig  0.545289  0.174336 -0.000327 -0.011642 -0.019539 -0.415149
# type_CASH_IN    0.512177  0.131897  0.034626  0.020902 -0.165574  0.677516
# type_CASH_OUT  -0.043098 -0.425476  0.690667 -0.325917  0.008654 -0.214684
# type_DEBIT     -0.025163 -0.078917  0.215110  0.908018  0.264573 -0.088965
# type_PAYMENT   -0.346305  0.540089 -0.219053 -0.161567  0.300061 -0.193422
# type_TRANSFER  -0.018071 -0.510181 -0.579547  0.103692 -0.428464 -0.241395
#
#                      PC7           PC8
# amount          0.139589  3.455357e-15
# oldbalanceOrg  -0.692101 -1.622522e-14
# newbalanceOrig  0.706683  1.817367e-14
# type_CASH_IN   -0.033947  4.806732e-01
# ...

# %%
top_features_per_component = 5  # Adjust this number as needed
for i in range(3):  # Analyze the first 3 principal components
    print(f"\nTop {top_features_per_component} features contributing to PC{i+1}:")
    sorted_loading_scores = loading_scores[f'PC{i+1}'].abs().sort_values(ascending=False)
    print(sorted_loading_scores.head(top_features_per_component))
# Out:
# Top 5 features contributing to PC1:
# oldbalanceOrg     0.546220
# newbalanceOrig    0.545289
# type_CASH_IN      0.512177
# type_PAYMENT      0.346305
# amount            0.138686
# Name: PC1, dtype: float64
#
# Top 5 features contributing to PC2:
# type_PAYMENT      0.540089
# type_TRANSFER     0.510181
# amount            0.449447
# type_CASH_OUT     0.425476
# newbalanceOrig    0.174336
# Name: PC2, dtype: float64
#
# Top 5 features contributing to PC3:
# type_CASH_OUT    0.690667
# type_TRANSFER    0.579547
# amount           0.298582
# type_PAYMENT     0.219053
# type_DEBIT       0.215110
# Name: PC3, dtype: float64

# %%
# Step 3: Convert PCA output to DataFrame and add 'isFraud' for correlation analysis
pca_df = pd.DataFrame(X_pca, columns=[f'PC{i+1}' for i in range(X.shape[1])])
pca_df['isFraud'] = y.reset_index(drop=True)

# Step 4: Calculate correlation between each principal component and 'isFraud'
correlations = pca_df.corr()['isFraud'].drop('isFraud')

# Display the correlations
print("Correlation between principal components and 'isFraud':")
print(correlations)

# Identify the most relevant components based on absolute correlation
most_relevant_components = correlations.abs().sort_values(ascending=False)
print("\nPrincipal components most correlated with 'isFraud':")
print(most_relevant_components)
# Out:
# Correlation between principal components and 'isFraud':
# PC1   -0.008702
# PC2   -0.392795
# PC3   -0.007386
# PC4   -0.080916
# PC5   -0.030826
# PC6   -0.090997
# PC7   -0.286099
# PC8   -0.193439
# Name: isFraud, dtype: float64
#
# Principal components most correlated with 'isFraud':
# PC2    0.392795
# PC7    0.286099
# PC8    0.193439
# PC6    0.090997
# PC4    0.080916
# PC5    0.030826
# PC1    0.008702
# PC3    0.007386
# Name: isFraud, dtype: float64

# %%
# Select the top 3 principal components most correlated with 'isFraud'
top_n_components = 3
most_relevant_components = correlations.abs().sort_values(ascending=False).head(top_n_components).index

# Display loading scores for the top components
loading_scores = pd.DataFrame(pca.components_.T, columns=[f'PC{i+1}' for i in range(X.shape[1])], index=X.columns)

# Get the top features based on the loading scores of the most relevant components
top_features = set()
for component in most_relevant_components:
    sorted_loading_scores = loading_scores[component].abs().sort_values(ascending=False)
    top_features.update(sorted_loading_scores.head(5).index)  # Taking top 5 features per component for more robust selection

# Display the selected top features (taking the top 5 unique features across the components)
top_features = list(top_features)[:top_n_components]  # Limit to 5 unique features
print("Top 5 features selected for SVM training:", top_features)
# Out:
# Top 5 features selected for SVM training: ['amount', 'type_CASH_IN', 'type_CASH_OUT']

# %% [markdown]
# #### Simpler Feature Selection

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd

# Assuming X and y are your feature matrix and target vector
model = RandomForestClassifier()
model.fit(X, y)

# Get feature importances
importances = model.feature_importances_
feature_importance_df = pd.DataFrame({'feature': X.columns, 'importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)

# Display the top features
print(feature_importance_df.head(10))
# Out:
#            feature  importance
# 2    oldbalanceOrg    0.178459
# 0             step    0.163575
# 1           amount    0.159211
# 4   oldbalanceDest    0.156555
# 5   newbalanceDest    0.136024
# 11   type_TRANSFER    0.069475
# 3   newbalanceOrig    0.059326
# 10    type_PAYMENT    0.044594
# 8    type_CASH_OUT    0.024190
# 7     type_CASH_IN    0.006459

# %%
top_features = ['oldbalanceDest', 'oldbalanceOrg', 'newbalanceDest', 'amount', 'newbalanceOrig']

X_top = X[top_features]

# %% [markdown]
# #### Training Preparation

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_top = scaler.fit_transform(X_top)

# %%
X_train_top, X_test_top, y_train_top, y_test_top = train_test_split(X_top, y, test_size=0.2, random_state=42)

print("Training set size:", X_train_top.shape, y_train_top.shape)
print("Testing set size:", X_test_top.shape, y_test_top.shape)
# Out:
# Training set size: (1856, 5) (1856,)
# Testing set size: (464, 5) (464,)

# %%
from qiskit import QuantumCircuit
from qiskit.visualization import plot_histogram
from qiskit.circuit.library import TwoLocal,ZZFeatureMap,PauliFeatureMap

import numpy as np

# %%
X_train_top
# Out:
# array([[-0.35827002, -0.31091876, -0.41468134, -0.35799139, -0.30881413],
#        [-0.35827002, -0.31512983, -0.41468134, -0.37855524, -0.30881413],
#        [-0.35624267, -0.30062608,  0.3582852 ,  2.26884514, -0.30881413],
#        ...,
#        [-0.02451839,  0.47845304, -0.37529132,  0.44164771,  0.62981297],
#        [-0.35827002, -0.31512983, -0.41468134, -0.34970875, -0.30881413],
#        [-0.28866972,  0.91750038, -0.39296045, -0.17945802,  0.95362996]])

# %% [markdown]
# #### Using Classical Ways

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC(kernel='linear', random_state=42)

svm_model.fit(X_train_top, y_train_top)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = svm_model.predict(X_test_top)

print("Accuracy:", accuracy_score(y_test_top, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test_top, y_pred))
print("Classification Report:\n", classification_report(y_test_top, y_pred))
# Out:
# Accuracy: 0.9568965517241379
# Confusion Matrix:
#  [[443   0]
#  [ 20   1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       443
#            1       1.00      0.05      0.09        21
#
#     accuracy                           0.96       464
#    macro avg       0.98      0.52      0.53       464
# weighted avg       0.96      0.96      0.94       464

# %% [markdown]
# #### Using the QSVC Model for predictions

# %%
from qiskit.circuit.library import EfficientSU2,ZFeatureMap

# %% [markdown]
# In this point we are gonna take advantage of the feature selection we implemented bofre. The main reason is that we dont have a lot of qubits.

# %%
feature_dimension = 3  # Number of features/qubits
reps = 1  # Number of repetitions
entanglement = 'full'  # Entanglement strategy

feature_map = ZFeatureMap(feature_dimension=feature_dimension, reps=reps)

# %%
from qiskit_machine_learning.kernels import FidelityQuantumKernel

quantum_kernel = FidelityQuantumKernel(feature_map=feature_map)

# %%
from qiskit_machine_learning.algorithms import QSVC

qsvc = QSVC(quantum_kernel=quantum_kernel)
# qsvc.fit(X_train_reduced, y_train_reduced)

# %%
import numpy as np

# Set the fraction of data to sample (10% here)
fraction = 0.1

# Calculate the number of rows to keep
n_samples = int(X_train_top.shape[0] * fraction)

# Randomly select indices for sampling
np.random.seed(42)  # For reproducibility
selected_indices = np.random.choice(X_train_top.shape[0], n_samples, replace=False)

# Use the selected indices to create the reduced dataset
X_train_reduced = X_train_top[selected_indices]
y_train_reduced = y[selected_indices]

# %%
X_train_reduced.shape
# Out:
# (185, 5)

# %%
qsvc.fit(X_train_reduced, y_train_reduced)

# %%
accuracy = qsvc.score(X_test_top, y_test_top)
print(f"Model accuracy: {accuracy * 100:.2f}%")

# %%
X_test_top.shape
# Out:
# (464, 5)

# %%
y_test_top.shape
# Out:
# (464,)

# %%
y_pred = qsvc.predict(X_test_top)

# %%
from sklearn.metrics import accuracy_score, f1_score
f1 = f1_score(y_test_top, y_pred, average='weighted')
print(f"Model F1 score (weighted): {f1:.2f}")
# Out:
# Model F1 score (weighted): 0.93

# %%
X_test_top.shape
# Out:
# (464, 5)

# %%
print("Accuracy:", accuracy_score(y_test_top, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test_top, y_pred))
print("Classification Report:\n", classification_report(y_test_top, y_pred))
# Out:
# Accuracy: 0.9547413793103449
# Confusion Matrix:
#  [[443   0]
#  [ 21   0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       443
#            1       0.00      0.00      0.00        21
#
#     accuracy                           0.95       464
#    macro avg       0.48      0.50      0.49       464
# weighted avg       0.91      0.95      0.93       464
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ### Now Testing our Model on a much bigger dataset

# %% [markdown]
# #### Preparing the bigger dataset

# %%
big_df
# Out:
#        step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0         1   PAYMENT    9839.64  C1231006815       170136.0       160296.36
# 1         1   PAYMENT    1864.28  C1666544295        21249.0        19384.72
# 2         1  TRANSFER     181.00  C1305486145          181.0            0.00
# 3         1  CASH_OUT     181.00   C840083671          181.0            0.00
# 4         1   PAYMENT   11668.14  C2048537720        41554.0        29885.86
# ...     ...       ...        ...          ...            ...             ...
# 99995    10   PAYMENT    4020.66  C1410794718       159929.0       155908.34
# 99996    10   PAYMENT   18345.49   C744303677         6206.0            0.00
# 99997    10   CASH_IN  183774.91   C104331851        39173.0       222947.91
# 99998    10  CASH_OUT   82237.17   C707662966         6031.0            0.00
# 99999    10   PAYMENT   20096.56  C1868032458       110117.0        90020.44
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd

def prepare_data_for_training(df, target_column='isFraud', sampling_ratio=95/5, top_features=None, test_size=0.2, random_state=42):
    """
    Prepares a dataset for training by balancing classes, selecting features, scaling, and splitting into train and test sets.

    Parameters:
        df (pd.DataFrame): The original dataset.
        target_column (str): The target column for classification.
        sampling_ratio (float): The ratio of non-fraud to fraud samples. Default is 95:5.
        top_features (list): List of top features to keep based on feature importance.
        test_size (float): The proportion of the dataset to include in the test split.
        random_state (int): The random seed for reproducibility.

    Returns:
        X_train, X_test, y_train, y_test: Prepared training and testing datasets.
    """

    print(df.shape)

    # Separate fraud and non-fraud transactions
    fraud_df = df[df[target_column] == 1]
    non_fraud_df = df[df[target_column] == 0]

    # Check the size of fraud and non-fraud subsets
    print("Size of fraud and non-fraud datasets:")
    print("Fraud:", fraud_df.shape, "Length of fraud_df:", len(fraud_df))
    print("Non-Fraud:", non_fraud_df.shape, "Length of non_fraud_df:", len(non_fraud_df))

    # Calculate the number of non-fraud samples needed for the specified ratio
    desired_non_fraud_count = int(len(fraud_df) * sampling_ratio)

    # Randomly sample the non-fraud data to the desired count
    non_fraud_sampled = non_fraud_df.sample(n=desired_non_fraud_count, random_state=random_state)

    # Concatenate fraud and sampled non-fraud data and shuffle
    balanced_df = pd.concat([fraud_df, non_fraud_sampled])
    balanced_df = balanced_df.sample(frac=1, random_state=random_state).reset_index(drop=True)

    print("-The balanced dataset now has shape of : ", balanced_df.shape)
    print(print("The amount of Fraud Transaction in the Balanced Dataset is: ",df[df[target_column] == 1].shape))


    # Print the class balance in the dataset
    print("Class balance after sampling:")
    balanced_df[target_column].value_counts(normalize=True) * 100


    # One-hot encode categorical columns
    X = pd.get_dummies(balanced_df, columns=['type'])

    # Remove columns containing 'name'
    X = X.loc[:, ~X.columns.str.contains('name')]

    # Convert all columns to int (optional if required by your dataset)
    X = X.astype(int)

    # Separate target and features
    y = X[target_column]
    X = X.drop(columns=[target_column])

    # Feature selection using RandomForest
    model = RandomForestClassifier(random_state=random_state)
    model.fit(X, y)

    importances = model.feature_importances_
    feature_importance_df = pd.DataFrame({'feature': X.columns, 'importance': importances})
    feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)

    print("Top 10 features based on importance:")
    print(feature_importance_df.head(10))

    # Select top features if provided; otherwise, use default top 5
    if top_features is None:
        top_features = feature_importance_df['feature'].head(3).tolist()

    X_top = X[top_features]

    # Scale the selected features
    scaler = StandardScaler()
    X_top = scaler.fit_transform(X_top)

    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_top, y, test_size=test_size, random_state=random_state)

    # Print the sizes of the train and test sets
    print("Training set size:", X_train.shape, y_train.shape)
    print("Testing set size:", X_test.shape, y_test.shape)

    return X_train, X_test, y_train, y_test

# %%
X_big_train_top, X_big_test_top, y_big_train_top, y_big_test_top = prepare_data_for_training(big_df)
# Out:
# (1000000, 11)
# Size of fraud and non-fraud datasets:
# Fraud: (535, 11) Length of fraud_df: 535
# Non-Fraud: (999465, 11) Length of non_fraud_df: 999465
# -The balanced dataset now has shape of :  (10700, 11)
# The amount of Fraud Transaction in the Balanced Dataset is:  (535, 11)
# None
# Class balance after sampling:
# Top 10 features based on importance:
#            feature  importance
# 2    oldbalanceOrg    0.210891
# 1           amount    0.191553
# 5   newbalanceDest    0.173758
# 4   oldbalanceDest    0.102919
# 0             step    0.092789
# 3   newbalanceOrig    0.086432
# 11   type_TRANSFER    0.076810
# 10    type_PAYMENT    0.027503
# 8    type_CASH_OUT    0.022533
# 7     type_CASH_IN    0.014511
# Training set size: (8560, 5) (8560,)
# Testing set size: (2140, 5) (2140,)

# %% [markdown]
# #### Now testing the QSVC

# %%
qsvc.fit(X_big_train_top, y_big_train_top)

# %%
accuracy = qsvc.score(X_big_test_top, y_big_test_top)
print(f"Model accuracy: {accuracy * 100:.2f}%")

# %%
y_big_pred = qsvc.predict(X_big_test_top)

# %%
from sklearn.metrics import accuracy_score, f1_score
f1 = f1_score(y_test_top, y_pred, average='weighted')
print(f"Model F1 score (weighted): {f1:.2f}")
